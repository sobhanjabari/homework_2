# %%
import os

print("DB_HOST:", os.getenv("DB_HOST"))
print("DB_PORT:", os.getenv("DB_PORT"))
print("DB_NAME:", os.getenv("DB_NAME"))
print("DB_USER:", os.getenv("DB_USER"))
print("DB_PASSWORD is set:", bool(os.getenv("DB_PASSWORD")))
# Out:
# DB_HOST: None
# DB_PORT: None
# DB_NAME: None
# DB_USER: None
# DB_PASSWORD is set: False
